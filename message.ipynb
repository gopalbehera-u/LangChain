# %%
print("hello")
# Out:
# hello

# %%
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage

# %%
from langchain_openai import ChatOpenAI
import os
os.environ['OPENAI_API_KEY']='key'

# %%
model=ChatOpenAI(
    model='gpt-5.4-mini',
    temperature=1
)

# %%
message=[
    SystemMessage(content='you are a helpfull assisant'),
    HumanMessage(content='Tell me about jjk in 3 lines')
]

# %%
result=model.invoke(message)
message.append(AIMessage(result.content))
print(message)
# Out:
# [SystemMessage(content='you are a helpfull assisant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me about jjk in 3 lines', additional_kwargs={}, response_metadata={}), AIMessage(content='JJK, or *Jujutsu Kaisen*, is a dark fantasy manga/anime about sorcerers fighting curses born from negative human emotions.  \nIt follows Yuji Itadori, a high school student who gets pulled into the world of jujutsu after becoming the host of a powerful curse named Sukuna.  \nThe series is known for its intense battles, strong characters, and a mix of horror, action, and emotional storylines.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]
