# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
url='https://reference.langchain.com/python/langchain-core/documents/base/Document'
loader=WebBaseLoader(url)

# %%
docs=loader.load()

# %%
print(len(docs))
# Out:
# 1

# %%
print(docs[0].page_content)
# Out:
# Document | langchain_core | LangChain ReferenceLangChain Reference home pageSearch...âŒ˜KAsk AIGitHubMain DocsDeep AgentsLangChainLangGraphIntegrationsLangSmithOverviewLangChainLangChain CoreOverviewCachesCallbacksDocumentsDocument loadersEmbeddingsExceptionsLanguage modelsSerializationOutput parsersPromptsRate limitersRetrieversRunnablesUtilitiesVector storesMCP AdaptersStandard TestsText SplittersLangChain ClassicâŒ˜ILangChain AssistantNewHistoryAsk a question to get startedEnter to sendâ€¢Shift+Enter new lineMenuNavigationProjectsLangChainLangChain CoreOverviewCachesCallbacksDocumentsDocument loadersEmbeddingsExceptionsLanguage modelsSerializationOutput parsersPromptsRate limitersRetrieversRunnablesUtilitiesVector storesMCP AdaptersStandard TestsText SplittersLangChain ClassicLanguagePythonJavaScriptThemeLightDarkPythonlangchain-coredocumentsbaseDocumentClassv1.6.1 (latest)â—�Since v0.1DocumentCopyDocument(
#     self,
#     page_content: str,
#     **kwargs: Any = {},
# )BasesBaseMediaUsed in DocsBuild a semantic search engine with LangChain(MODULE_NAME) integrationAI21SemanticTextSplitter integrationAstra DB integrationAzure database for postgresql - flexible server integration+15 more(24 more not shown)ConstructorsAttributesMethodsInherited fromBaseMediaAttributesAid: str | Noneâ€”An optional identifier for the document.Ametadata: dict[Any, Any]â€”Arbitrary metadata associated with the content.Inherited fromSerializableAttributesAView source on GitHubVersion Historylc_secrets: dict[str, str]â€”A map of constructor argument names to secret ids.Alc_attributes: dict[str, Any]â€”List of attribute names that should be included in the serialized kwargs.Amodel_configMethodsMlc_idâ€”Return a unique identifier for this class for serialization purposes.Mto_jsonâ€”Serialize the object to JSON.Mto_json_not_implementedâ€”Serialize a "not implemented" object.constructor__init__NameTypepage_contentstrattributepage_content: strattributetype: Literal['Document']methodis_lc_serializablemethodget_lc_namespaceClass for storing a piece of text and associated metadata.
# NoteDocument is for retrieval workflows, not chat I/O. For sending text
# to an LLM in a conversation, use message types from langchain.messages.Example:
# from langchain_core.documents import Document
#
# document = Document(
#     page_content="Hello, world!", metadata={"source": "https://example.com"}
# )String text.Return True as this class is serializable.Get the namespace of the LangChain object.

# %%
print(docs[0].metadata)
# Out:
# {'source': 'https://reference.langchain.com/python/langchain-core/documents/base/Document', 'title': 'Document | langchain_core | LangChain Reference', 'description': 'Python API reference for documents.base.Document in langchain_core. Part of the LangChain ecosystem.', 'language': 'en'}

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os 
os.environ['OPENAI_API_KEY']="your key"

# %%
llm= ChatOpenAI(
    model='gpt-5.4-mini',
    temperature=1
)

# %%
parser=StrOutputParser()

# %%
promt=PromptTemplate(
    template="'Answer the following question \n {question} from the following text - \n {text} ",
    input_variables=['question','text']
)

# %%
chain=promt|llm|parser

# %%
print(chain.invoke({'question':'What is the prodcut that we are talking about?', 'text':docs[0].page_content}))
# Out:
# The product being talked about is **LangChain Core**, specifically the **`Document` class** in the `langchain_core.documents` module.
