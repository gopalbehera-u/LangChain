# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableSequence,RunnableParallel

# %%
prompt1=PromptTemplate(
    template="wriet a tweet about the {topic}",
    input_variables=['topic']
)

# %%
prompt2=PromptTemplate(
    template="generate linkedin post on this {topic}",
    input_variables=['topic']
)

# %%
psrser=StrOutputParser()
model=ChatOpenAI(model='gpt-5.4-mini')
import os 
os.environ['OPENAI_API_KEY']="your key"

# %%
parallel_chain=RunnableParallel({
    'tweet':RunnableSequence(prompt1,model,psrser),
    'linkedin':RunnableSequence(prompt2,model,psrser)
})

# %%
result=parallel_chain.invoke({'topic':"AI"})

# %%
print(result)
# Out:
# {'tweet': 'Here’s a tweet you can use:\n\n**AI is changing the way we work, create, and solve problems faster than ever. The future isn’t coming — it’s already here. #AI #Innovation**\n\nIf you want, I can make it **more funny, more professional, or more viral**.', 'linkedin': 'Absolutely — here’s a polished LinkedIn post you can use:\n\n---\n\n🚀 **AI is no longer just a buzzword — it’s becoming a real productivity multiplier.**\n\nWhat’s exciting about AI is not just automation, but how it helps us:\n- work faster\n- make better decisions\n- unlock new ideas\n- focus more on high-value tasks\n\nThe real opportunity isn’t replacing people — it’s **empowering people** to do more of what matters.\n\nWe’re at a point where businesses and professionals who learn to use AI effectively will have a serious edge in speed, creativity, and innovation.\n\nThe question is no longer *“Should we use AI?”*  \nIt’s *“How do we use AI responsibly and strategically?”*\n\n#AI #ArtificialIntelligence #Innovation #Productivity #FutureOfWork #Technology #DigitalTransformation\n\n---\n\nIf you want, I can also create:\n1. a **more professional/corporate version**,  \n2. a **thought-leadership style post**, or  \n3. a post tailored to a **specific AI product or project**.'}

# %%
print(result['tweet'])
# Out:
# Here’s a tweet you can use:
#
# **AI is changing the way we work, create, and solve problems faster than ever. The future isn’t coming — it’s already here. #AI #Innovation**
#
# If you want, I can make it **more funny, more professional, or more viral**.

# %%
print(result['linkedin'])
# Out:
# Absolutely — here’s a polished LinkedIn post you can use:
#
# ---
#
# 🚀 **AI is no longer just a buzzword — it’s becoming a real productivity multiplier.**
#
# What’s exciting about AI is not just automation, but how it helps us:
# - work faster
# - make better decisions
# - unlock new ideas
# - focus more on high-value tasks
#
# The real opportunity isn’t replacing people — it’s **empowering people** to do more of what matters.
#
# We’re at a point where businesses and professionals who learn to use AI effectively will have a serious edge in speed, creativity, and innovation.
#
# The question is no longer *“Should we use AI?”*
# It’s *“How do we use AI responsibly and strategically?”*
#
# #AI #ArtificialIntelligence #Innovation #Productivity #FutureOfWork #Technology #DigitalTransformation
#
# ---
#
# If you want, I can also create:
# 1. a **more professional/corporate version**,
# 2. a **thought-leadership style post**, or
# 3. a post tailored to a **specific AI product or project**.
