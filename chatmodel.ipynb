# %%
from langchain_openai  import  ChatOpenAI

# %%
llm=ChatOpenAI(
    model='gpt-5.4-mini',max_completion_tokens=100,
    temperature=0
)

# %%
result=llm.invoke("who is prime minister of india ?")

# %%
result.content
# Out:
# 'The Prime Minister of India is **Narendra Modi**.'
