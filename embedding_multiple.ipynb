# %%
import os
os.environ['OPENAI_API_KEY']='KEY'
from langchain_openai import OpenAIEmbeddings

# %%
embeding=OpenAIEmbeddings(model='text-embedding-3-small',dimensions=32)

# %%
docs=[
    "gopal is good boy",
    "rahul is fav player",
    "rohit playes well"
]
# No Creadits 
#result=embeding.embed_documents(docs)

# print(list(result))
