# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
import os
os.environ['OPENAI_API_KEY']='key'

# %%
prompt=PromptTemplate(
    template='generate 5 interesting facts about {topic}',
    input_variables=['topic']
)

# %%
model=ChatOpenAI(
    model='gpt-5.4-mini',
    temperature=1
)

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
parser=StrOutputParser()
chain=prompt | model | parser

# %%
ressult=chain.invoke({"topic":'cricket'})

# %%
print(ressult)
# Out:
# Here are 5 interesting facts about cricket:
#
# 1. **Cricket has been played for centuries**
#    The game dates back to at least the 16th century in England, making it one of the oldest team sports still played today.
#
# 2. **A cricket match can last up to 5 days**
#    Test cricket, the longest format of the game, is played over five days and still can end in a draw.
#
# 3. **The cricket ball is very hard and dangerous**
#    A cricket ball is made of cork, leather, and string, and can travel at speeds over 90 mph (145 km/h), which is why helmets and protective gear are important.
#
# 4. **The longest recorded cricket match lasted 12 days**
#    In 1939, a Test match between South Africa and England was scheduled for 10 days but lasted 12 days in total due to travel delays and ended without a result.
#
# 5. **Cricket is hugely popular worldwide**
#    It’s especially loved in countries like India, Australia, England, Pakistan, South Africa, and the West Indies, with billions of fans globally.
#
# If you want, I can also give you **5 fun facts**, **5 surprising facts**, or **5 facts for kids**.

# %%
# %pip install grandalf
chain.get_graph().print_ascii()
# Out:
#      +-------------+
#      | PromptInput |
#      +-------------+
#             *
#             *
#             *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#             *
#             *
#             *
#       +------------+
#       | ChatOpenAI |
#       +------------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
