# %%
from langchain_core.prompts import PromptTemplate
from langchain_community.document_loaders import CSVLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

# %%
llm=ChatOpenAI(
    model='gpt-5.4-mini',
    temperature=1
)

# %%
loader=CSVLoader(file_path=r'C:\Users\beher\OneDrive\Desktop\langchain\Churn_Modelling.csv')

# %%
docs=loader.load()

# %%
print(len(docs))
# Out:
# 10000

# %%
print(docs[0].page_content)
# Out:
# apst: 1
# CustomerId: 15634602
# Surname: Hargrave
# CreditScore: 619
# Geography: delhi
# Gender: Female
# Age: 42
# Tenure: 2
# Balance: 0
# NumOfProducts: 1
# HasCrCard: 1
# IsActiveMember: 1
# EstimatedSalary: 101348.88
# Exited: 1

# %%
print(docs[1].page_content)
# Out:
# apst: 2
# CustomerId: 15647311
# Surname: Hill
# CreditScore: 608
# Geography: bangalore
# Gender: Female
# Age: 41
# Tenure: 1
# Balance: 83807.86
# NumOfProducts: 1
# HasCrCard: 0
# IsActiveMember: 1
# EstimatedSalary: 112542.58
# Exited: 0
