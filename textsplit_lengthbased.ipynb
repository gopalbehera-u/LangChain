# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text="""
Paragraphs are the building blocks of papers.
 Many students define paragraphs in terms of length: a paragraph is a group of at least five sentences,
  a paragraph is half a page long, etc. In reality, though, the unity and coherence of ideas among sentences is what constitutes a paragraph.
   A paragraph is defined as “a group of sentences or a single sentence that forms a unit” (Lunsford and Connors 116). Length and appearance do not determine whether a section in a paper is a paragraph. For instance, in some styles
    of writing, particularly journalistic styles, a paragraph can be just one sentence long.
    Ultimately, a paragraph is a sentence or group of sentences that support one main idea. In this handout, we will refer to this as the “controlling idea,” because it controls what happens in the rest of the paragraph.

"""

# %%
spliter=CharacterTextSplitter(
    chunk_size=70, chunk_overlap=30,separator=' '
)

# %%
result=spliter.split_text(text)

# %%
print(result)
# Out:
# ['Paragraphs are the building blocks of papers.\n Many students define', 'papers.\n Many students define paragraphs in terms of length: a', 'in terms of length: a paragraph is a group of at least five', 'is a group of at least five sentences,\n a paragraph is half a page', 'a paragraph is half a page long, etc. In reality, though, the unity', 'In reality, though, the unity and coherence of ideas among sentences', 'of ideas among sentences is what constitutes a paragraph.\n A paragraph', 'a paragraph.\n A paragraph is defined as “a group of sentences or a', 'as “a group of sentences or a single sentence that forms a unit”', 'sentence that forms a unit” (Lunsford and Connors 116). Length and', 'and Connors 116). Length and appearance do not determine whether a', 'do not determine whether a section in a paper is a paragraph. For', 'in a paper is a paragraph. For instance, in some styles\n of writing,', 'in some styles\n of writing, particularly journalistic styles, a', 'journalistic sty
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader=PyPDFLoader(r'C:\Users\beher\OneDrive\Desktop\langchain\DOCS\Gopal_Behera_Resume (3) (1).pdf')

# %%
docs=loader.load()

# %%
result=spliter.split_documents(docs)

# %%
print(result[7].page_content)
# Out:
# Scikit-learn, Pandas, and NumPy, with hands-on experience building
