# %%
print('hello')
# Out:
# hello

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage
import os
os.environ['OPENAI_API_KEY']='key'

# %%
model=ChatOpenAI(
    model='gpt-5.4-mini',
    temperature=1
)

# %%
chat_history=[SystemMessage(content='You are the helpful AI assisant')]
while  True:
    user_input=input("You : ")
    chat_history.append(HumanMessage(user_input))
    if user_input in ['exit','stop','q']: 
        break
    rsult=model.invoke(chat_history)
    chat_history.append(AIMessage(rsult.content))
    print("AI: ",rsult.content)
print(chat_history)
# Out:
# AI:  Hi! How can I help you today?
# AI:  I’m doing well, thanks! How about you?
# AI:  4 + 6 = 10
# AI:  10 × 50 = 500
# [SystemMessage(content='You are the helpful AI assisant', additional_kwargs={}, response_metadata={}), HumanMessage(content='hi ', additional_kwargs={}, response_metadata={}), AIMessage(content='Hi! How can I help you today?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='how r u', additional_kwargs={}, response_metadata={}), AIMessage(content='I’m doing well, thanks! How about you?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='what 4+6', additional_kwargs={}, response_metadata={}), AIMessage(content='4 + 6 = 10', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='multiply that output into 50 ', additional_kwargs={}, response_metadata={}), AIMessage(content='10 × 50 = 500', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='q', additional_kwargs={}, response_metadata={})]
