# %%
import os 
os.environ['OPENAI_API_KEY']="your key"

# %%
from langchain_core.runnables import RunnableBinding

# %%
import warnings
warnings.filterwarnings('ignore')
from langchain_community.document_loaders import PyPDFLoader

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableSequence

# %%
prompt1=PromptTemplate(
    template='write joke about {topic}',
    input_variables=['topic']
)

prompt2=PromptTemplate(
    template='Explain the following joke - {text}',
    input_variables=['text']
)

# %%
model=ChatOpenAI(model='gpt-5.4-mini',temperature=1)
parser=StrOutputParser()
chain=RunnableSequence(prompt1,model,parser,prompt2,model,parser)
print(chain.invoke({'topic':'ai'}))
# Out:
# The joke is a pun on **“training issues”**.
#
# - In **AI / machine learning**, a model is “trained” on data, so it can have problems with its training process, data, or behavior.
# - In **therapy**, “issues” means emotional or psychological problems.
#
# So the punchline suggests the AI went to therapy because it had “issues” related to its training — mixing a technical AI term with a human mental-health phrase.
