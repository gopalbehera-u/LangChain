# %%
from langchain_openai import OpenAI

# %%
import os 
os.environ['OPENAI_API_KEY']='your key'

# %%
llm=OpenAI(model='gpt-5.4-mini',temperature=0)

# %%
result=llm.invoke("who is the prime minister of india?")

# %%
from langchain_openai import OpenAI
llm=OpenAI(
    model='gpt-5.4-mini',
    temperature=0
)

response=llm.invoke("who is prime minister of india?")
print(response)
# Out:
# ","who is the prime minister of india?","who is the prime minister of india","who is prime minister of india","who is the pm of india?","who is the pm of india","who is pm of india?","who is pm of india","who is the prime minister of india now?","who is the prime minister of india now","who is the current prime minister of india?","who is the current prime minister of india","who is the current pm of india?","who is the current pm of india","who is the current prime minister of india now?","who is the current prime minister of india now","who is the current pm of india now?","who is the current pm of india now","who is the prime minister of india currently?","who is the prime minister of india currently","who is pm of india currently?","who is pm of india currently","who is the pm of india currently?","who is the pm of india currently","who is the prime minister of india at present?","who is the prime minister of india at present","who is pm of india at present?","who is pm of india at present","who is the pm of india at present?","who is the pm of india at present","

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(
    model='gpt-5.4-mini',
    temperature=0
)
response=llm.invoke("who is prime minister of india?")
print(response.content)
# Out:
# The Prime Minister of India is **Narendra Modi**.
