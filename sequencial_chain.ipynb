# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
import os 
os.environ['OPENAI_API_KEY']="key"

# %%
model=ChatOpenAI(
    model='gpt-5.4-mini',
    temperature=1
)
parser=StrOutputParser()

# %%
prompt1=PromptTemplate(
    template='Generate a detailed report on {topic}',
    input_variables=['topic']
)

prompt2=PromptTemplate(
    template='generate a 5 pointer summary from the folliwing text \n {text}',
    input_variables=['text']
)

# %%
chain=prompt1 |model|parser|prompt2|model|parser

# %%
result=chain.invoke({'topic':'freefire'})

# %%
print(result)
# Out:
# Here’s a **5-point summary** of the text:
#
# 1. **Free Fire is a popular mobile battle royale game** developed by Garena, released in 2017, and especially successful in regions like South Asia, Southeast Asia, Latin America, and Africa.
#
# 2. **The game features fast-paced survival gameplay** where up to 50 players fight to be the last one standing, with matches usually lasting around 10 minutes.
#
# 3. **Free Fire offers many gameplay features**, including character-based skills, a wide range of weapons and gear, different game modes, pets, and cosmetic items for customization.
#
# 4. **Its strong performance on low-end devices** has helped make it widely accessible and popular, especially in markets where high-spec smartphones are less common.
#
# 5. **Free Fire has a major esports scene and active community**, but it also faces criticism for issues like microtransactions, cheating, addiction concerns, and fairness balance.

# %%
chain.get_graph().print_ascii()
# Out:
#      +-------------+
#      | PromptInput |
#      +-------------+
#             *
#             *
#             *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#             *
#             *
#             *
#       +------------+
#       | ChatOpenAI |
#       +------------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
#             *
#             *
#             *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#             *
#             *
#             *
#       +------------+
#       | ChatOpenAI |
#       +------------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
